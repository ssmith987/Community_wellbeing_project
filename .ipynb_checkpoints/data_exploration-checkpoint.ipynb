# %%
#Loading all dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functools import reduce

# %%
#Getting a csv files that has zip as well as city in SD county
median_home_price = pd.read_csv("ZipCode_File/Zip_Zhvi_AllHomes.csv")
median_home_price = median_home_price.loc[median_home_price['CountyName'] == 'San Diego'].rename(columns={'RegionName':'zip'})

#Now only storing the required columns form the csv file and storing it in another csv file 
median_home_price_sd = median_home_price[['zip', 'City', 'Metro', 'CountyName']].drop_duplicates()
median_home_price_sd.to_csv('City_zip.csv')

#Reading the same csv that has been created above
city_zip = pd.read_csv('City_zip.csv')
city_zip.head()
# Out:
#    Unnamed: 0    zip         City               Metro CountyName
# 0         117  91910  Chula Vista  San Diego-Carlsbad  San Diego
# 1         176  92126    San Diego  San Diego-Carlsbad  San Diego
# 2         197  91911  Chula Vista  San Diego-Carlsbad  San Diego
# 3         221  92109    San Diego  San Diego-Carlsbad  San Diego
# 4         224  92101    San Diego  San Diego-Carlsbad  San Diego

# %%
#Reading another csv file that has the age and gender data by SD zip code
population_age_estimate = pd.read_csv('CSV Files/age_estimate_by_zip.csv')

#Only storing the data of 2020
population_age_estimate = population_age_estimate.loc[population_age_estimate['year'] == 2020]
population_age_estimate.head()
# Out:
#     Unnamed: 0 group_10yr  population     sex  year    zip
# 27          27   Under 10         928  Female  2020  91901
# 28          28   10 to 19        1066  Female  2020  91901
# 29          29   20 to 29         832  Female  2020  91901
# 30          30   30 to 39         928  Female  2020  91901
# 31          31   40 to 49        1110  Female  2020  91901

# %%
#Creating the population of male and female in two different data frames
population_df = population_age_estimate.loc[population_age_estimate['group_10yr'] == 'Total Population']  
population_fem = population_df.loc[population_df['sex'] == 'Female']
population_male = population_df.loc[population_df['sex'] == 'Male']

population_df.head()
# Out:
#      Unnamed: 0        group_10yr  population     sex  year    zip
# 36           36  Total Population        8882  Female  2020  91901
# 46           46  Total Population        9004    Male  2020  91901
# 47           47  Total Population       17886   Total  2020  91901
# 198         198  Total Population        9123  Female  2020  91902
# 208         208  Total Population        8750    Male  2020  91902

# %%
#Merging the City & Zip csv file with male population file on zip to get the male population by each city in SD County
city_pop_male = pd.merge(population_male, city_zip, on ='zip', how= 'inner')
city_pop_male.dropna()
city_pop_male = city_pop_male[['City', 'population']].dropna()
city_pop_male = pd.DataFrame(city_pop_male.groupby('City')['population'].sum()).reset_index().rename(columns= {'population' : 'Male'})
city_pop_male.head()
# Out:
#               City  Male
# 0           Alpine  9004
# 1           Bonita  8750
# 2          Bonsall  2579
# 3  Borrego Springs  2350
# 4            Campo  2442

# %%
#Merging the City & Zip csv file with female population file on zip to get the female population by each city in SD County
city_pop_fem = pd.merge(population_fem, city_zip, on ='zip', how= 'inner')
city_pop_fem.dropna()
city_pop_fem = city_pop_fem[['City', 'population']].dropna()
city_pop_fem = pd.DataFrame(city_pop_fem.groupby('City')['population'].sum()).reset_index().rename(columns= {'population' : 'Female'})
city_pop_fem.head()
# Out:
#               City  Female
# 0           Alpine    8882
# 1           Bonita    9123
# 2          Bonsall    2598
# 3  Borrego Springs    2366
# 4            Campo    2035

# %%
#Now merging the female and male population data frame on city to get both information in one dataframe
fem_male_pop = pd.merge(city_pop_fem, city_pop_male, on = 'City', how = 'inner')
fem_male_pop = fem_male_pop.set_index('City')
fem_male_pop.head()
# Out:
#                  Female  Male
# City
# Alpine             8882  9004
# Bonita             9123  8750
# Bonsall            2598  2579
# Borrego Springs    2366  2350
# Campo              2035  2442

# %%
#Plotting a stacked bar graph of male and female population
fem_male_pop.loc[:, ['Female', 'Male']].plot.bar(stacked=True, figsize = (15,10))
#plt.xticks(rotation=45)
plt.grid()
plt.xlabel('San Diego County Cities')
plt.ylabel('Population')
plt.title('Population By Gender & City')
# Out:
# Text(0.5,1,'Population By Gender & City')

# %%
#Now from the same csv file getting the age data.
#Combining Under 10 and 10 to 19 in one group called Minor and getting the population by zip
age_est_minor = population_age_estimate.loc[(population_age_estimate['group_10yr'] == 'Under 10')|(population_age_estimate['group_10yr']=='10 to 19')]
age_est_minor = age_est_minor[['group_10yr', 'population', 'zip']]
age_est_minor = pd.DataFrame(age_est_minor.groupby('zip')['population'].sum()).reset_index().rename(columns={'population':'Minor'})
age_est_minor.head()
# Out:
#      zip  Minor
# 0  91901   4228
# 1  91902   3932
# 2  91905    509
# 3  91906   1162
# 4  91910  20170

# %%
#Combining 4 different groups of 50+ in one as Senior and getting the population by zip
age_est_senior = population_age_estimate.loc[(population_age_estimate['group_10yr'] == '50 to 59')|
                                             (population_age_estimate['group_10yr']=='60 to 69')|
                                             (population_age_estimate['group_10yr']=='70 to 79')|
                                             (population_age_estimate['group_10yr']=='80+')]
age_est_senior = age_est_senior[['group_10yr', 'population', 'zip']]
age_est_senior = pd.DataFrame(age_est_senior.groupby('zip')['population'].sum()).reset_index().rename(columns={'population':'Seniors'})
age_est_senior.head()
# Out:
#      zip  Seniors
# 0  91901     7923
# 1  91902     7887
# 2  91905      841
# 3  91906     1822
# 4  91910    27464

# %%
#Getting the no. of 20 to 29 by each zip
age_est_20_29 = population_age_estimate.loc[(population_age_estimate['group_10yr'] == '20 to 29')]
age_est_20_29 = age_est_20_29[['group_10yr', 'population', 'zip']]
age_est_20_29 = pd.DataFrame(age_est_20_29.groupby('zip')['population'].sum()).reset_index().rename(columns={'population':'20 to 29'})
age_est_20_29.head()
# Out:
#      zip  20 to 29
# 0  91901      1855
# 1  91902      2179
# 2  91905       164
# 3  91906       491
# 4  91910     11439

# %%
#Getting the no. of 30 to 39 by each zip
age_est_30_39 = population_age_estimate.loc[(population_age_estimate['group_10yr'] == '30 to 39')]
age_est_30_39 = age_est_30_39[['group_10yr', 'population', 'zip']]
age_est_30_39 = pd.DataFrame(age_est_30_39.groupby('zip')['population'].sum()).reset_index().rename(columns={'population':'30 to 39'})
age_est_30_39.head()
# Out:
#      zip  30 to 39
# 0  91901      1775
# 1  91902      1916
# 2  91905       188
# 3  91906       526
# 4  91910      9449

# %%
#Getting the no. of 40 to 49 by each zip
age_est_40_49 = population_age_estimate.loc[(population_age_estimate['group_10yr'] == '40 to 49')]
age_est_40_49 = age_est_40_49[['group_10yr', 'population', 'zip']]
age_est_40_49 = pd.DataFrame(age_est_40_49.groupby('zip')['population'].sum()).reset_index().rename(columns={'population':'40 to 49'})
age_est_40_49.head()
# Out:
#      zip  40 to 49
# 0  91901      2105
# 1  91902      1959
# 2  91905       207
# 3  91906       476
# 4  91910      9217

# %%
#Creating a list which has all the data frames of different age groups
all_df = [age_est_minor, age_est_20_29, age_est_30_39, age_est_40_49, age_est_senior]

#Using the lambda functions combinig all the different age groups by zip
all_age_df = reduce(lambda left,right: pd.merge(left,right, on = 'zip', how = 'outer'), all_df)

#Merging the gae data with city data on zip
all_age_df = pd.merge(city_zip, all_age_df, on='zip', how='outer').dropna()

#Getting the sum of each age group by the SD cities
all_age_df = all_age_df[['City', 'Minor', '20 to 29', '30 to 39', '40 to 49', 'Seniors']]
all_age_df = all_age_df.groupby('City')['Minor', '20 to 29', '30 to 39', '40 to 49', 'Seniors'].sum()
all_age_df.head()
# Out:
#                  Minor  20 to 29  30 to 39  40 to 49  Seniors
# City
# Alpine            4228      1855      1775      2105     7923
# Bonita            3932      2179      1916      1959     7887
# Bonsall           1188       518       552       590     2329
# Borrego Springs    933       419       301       352     2711
# Campo             1162       491       526       476     1822

# %%
#Plotting a stacked bar graph of eavh age group population
all_age_df.loc[:, ['Minor', '20 to 29', '30 to 39', '40 to 49', 'Seniors']].plot.bar(stacked=True, figsize = (15,10))
#plt.xticks(rotation=45)
plt.grid()
plt.xlabel('San Diego County Cities')
plt.ylabel('Population')
plt.title('Population By Age Group & Cities')
# Out:
# Text(0.5,1,'Population By Age Group & Cities')
