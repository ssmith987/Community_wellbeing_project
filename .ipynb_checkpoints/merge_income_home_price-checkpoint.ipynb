# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
median_income_forecast = pd.read_csv("CSV files/median_income_estimate_by_zip.csv")
median_income_df = pd.DataFrame(median_income_forecast)

# %%
median_income_df.head()
# Out:
#    Unnamed: 0  median_inc  year    zip
# 0           0       80290  2016  91901
# 1           1       87540  2016  91902
# 2           2       35859  2016  91905
# 3           3       38053  2016  91906
# 4           4       50274  2016  91910

# %%
median_home_price = pd.read_csv("ZipCode_File/Zip_Zhvi_AllHomes.csv")

# %%
median_home_price_df = pd.DataFrame(median_home_price)

median_home_price_df.head()
# Out:
#    RegionID  RegionName      City State                             Metro  \
# 0     61639       10025  New York    NY       New York-Newark-Jersey City
# 1     84654       60657   Chicago    IL          Chicago-Naperville-Elgin
# 2     61637       10023  New York    NY       New York-Newark-Jersey City
# 3     91982       77494      Katy    TX  Houston-The Woodlands-Sugar Land
# 4     84616       60614   Chicago    IL          Chicago-Naperville-Elgin
#
#   CountyName  SizeRank   1996-04   1996-05   1996-06   ...     2017-12  \
# 0   New York         1  171600.0  171600.0  171400.0   ...     1138100
# 1       Cook         2  158400.0  159700.0  160700.0   ...      347500
# 2   New York         3  347900.0  349600.0  351100.0   ...     1565000
# 3     Harris         4  210400.0  212200.0  212200.0   ...      321100
# 4       Cook         5  192500.0  194500.0  196100.0   ...      425600
#
#    2018-01  2018-02  2018-03  2018-04  2018-05  2018-06  2018-07  2018-08  \
# ...

# %%
med_home_price_df = median_home_price_df.rename(columns={'RegionName':'zip'})

med_home_price_df
# Out:
#        RegionID    zip               City State  \
# 0         61639  10025           New York    NY
# 1         84654  60657            Chicago    IL
# 2         61637  10023           New York    NY
# 3         91982  77494               Katy    TX
# 4         84616  60614            Chicago    IL
# 5         93144  79936            El Paso    TX
# 6         91940  77449               Katy    TX
# 7         91733  77084            Houston    TX
# 8         61616  10002           New York    NY
# 9         61807  10467           New York    NY
# 10        84640  60640            Chicago    IL
# 11        97564  94109      San Francisco    CA
# 12        62037  11226           New York    NY
# 13        61630  10016           New York    NY
# 14        74101  37013          Nashville    TN
# 15        71831  32162       The Villages    FL
# 16        62087  11375           New York    NY
# 17        62045  11235           New York    NY
# ...

# %%
median_price_income = pd.merge(median_income_df, med_home_price_df, how='inner', on='zip')

# %%
median_price_income
# Out:
#      Unnamed: 0  median_inc  year    zip  RegionID            City State  \
# 0             0       80290  2016  91901     96538          Alpine    CA
# 1            69       80290  2016  91901     96538          Alpine    CA
# 2           138       80290  2016  91901     96538          Alpine    CA
# 3             1       87540  2016  91902     96539          Bonita    CA
# 4            70       87540  2016  91902     96539          Bonita    CA
# 5           139       87540  2016  91902     96539          Bonita    CA
# 6             3       38053  2016  91906     96542           Campo    CA
# 7            72       38053  2016  91906     96542           Campo    CA
# 8           141       38053  2016  91906     96542           Campo    CA
# 9             4       50274  2016  91910     96545     Chula Vista    CA
# 10           73       50274  2016  91910     96545     Chula Vista    CA
# 11          142       50274  2016  91910     96545     Chula Vista    CA
# ...

# %%
median_price_income.plot(kind='scatter', x='median_inc', y="2016-12", grid=True)
plt.ylabel('Median Home Price ($)')
plt.xlabel('Median Income ($)')
plt.title('Median Home Price vs Median Income ($)')
plt.plot()
# Out:
# []

# %%
plt.scatter(x=median_price_income['median_inc'], y=median_price_income['2016-12'], c=median_price_income['zip'])

# %%
median_price_income.plot(kind='bar', x='City', y="median_inc", grid=True)

# %%
city_grp = median_price_income.groupby(['City'], as_index=False).median()

# %%
print(city_grp['median_inc'].median())
print(city_grp['2016-12'].median())
# Out:
# 70615.25
# 515700.0

# %%
top_city_inc = city_grp.nlargest(3,'median_inc')
top_city_inc

bottom_city_inc = city_grp.nsmallest(3,'median_inc')
bottom_city_inc

t_b_city_inc = top_city_inc.append(bottom_city_inc)

t_b_city_inc
# Out:
#                City  Unnamed: 0  median_inc    year      zip  RegionID  \
# 25  Rancho Santa Fe       130.5    137533.0  2016.0  92079.0   96630.0
# 8           Del Mar       101.0    119435.0  2016.0  92014.0   96586.0
# 15            Jamul        83.0    104984.0  2016.0  91935.0   96558.0
# 3   Borrego Springs        95.0     27369.0  2016.0  92004.0   96579.0
# 20    National City        88.0     37235.0  2016.0  91950.0   96567.0
# 4             Campo        72.0     38053.0  2016.0  91906.0   96542.0
#
#     SizeRank   1996-04   1996-05   1996-06    ...        2017-12    2018-01  \
# 25   11367.5  819900.0  824050.0  828150.0    ...      2496200.0  2511550.0
# 8     6523.0  421000.0  421300.0  421600.0    ...      1779900.0  1800200.0
# 15    9306.0  228200.0  228400.0  228600.0    ...       635100.0   643700.0
# 3    11086.0  113200.0  113100.0  113100.0    ...       194200.0   198900.0
# 20    1382.0  120500.0  120400.0  120100.0    ...       405400.0   409800.0
# ...

# %%
t_b_city_inc.plot(kind='bar', x='City', y="median_inc")
t_b_city_inc.plot(kind='line', x='City', y='2016-12')

plt.plot()
# Out:
# []

# %%
city_grp['inc_price_comp'] = city_grp['median_inc']/city_grp['2016-12']*100
city_grp
# Out:
#                City  Unnamed: 0  median_inc    year      zip  RegionID  \
# 0            Alpine        69.0     80290.0  2016.0  91901.0   96538.0
# 1            Bonita        70.0     87540.0  2016.0  91902.0   96539.0
# 2           Bonsall        94.0     73411.0  2016.0  92003.0   96578.0
# 3   Borrego Springs        95.0     27369.0  2016.0  92004.0   96579.0
# 4             Campo        72.0     38053.0  2016.0  91906.0   96542.0
# 5          Carlsbad        98.5     90219.5  2016.0  92009.5   96582.5
# 6       Chula Vista        75.0     80812.0  2016.0  91913.0   96548.0
# 7          Coronado       223.0     93193.0  2016.0  92118.0   96660.0
# 8           Del Mar       101.0    119435.0  2016.0  92014.0   96586.0
# 9          Descanso        83.5     82484.5  2016.0  91939.0   96560.0
# 10         El Cajon       103.0     47251.0  2016.0  92020.0   96589.0
# 11        Encinitas       100.5     99579.0  2016.0  92015.5   96586.5
# ...

# %%
top_comp = city_grp.nlargest(3,'inc_price_comp')
top_comp

bottom_comp = city_grp.nsmallest(3,'inc_price_comp')
bottom_comp

t_b_comp = top_comp.append(bottom_comp)

t_b_comp
# Out:
#                City  Unnamed: 0  median_inc    year      zip  RegionID  \
# 9          Descanso        83.5     82484.5  2016.0  91939.0   96560.0
# 22     Pauma Valley       121.0     82870.0  2016.0  92061.0   96617.0
# 15            Jamul        83.0    104984.0  2016.0  91935.0   96558.0
# 26     San Clemente       243.0     38963.0  2016.0  92672.0   96982.0
# 7          Coronado       223.0     93193.0  2016.0  92118.0   96660.0
# 25  Rancho Santa Fe       130.5    137533.0  2016.0  92079.0   96630.0
#
#     SizeRank   1996-04   1996-05   1996-06       ...          2018-01  \
# 9    14118.0  160000.0  159900.0  159750.0       ...         443450.0
# 22   13311.0  205000.0  204300.0  203600.0       ...         508100.0
# 15    9306.0  228200.0  228400.0  228600.0       ...         643700.0
# 26    1451.0  223000.0  222100.0  221300.0       ...         951100.0
# 7     5031.0  392600.0  391700.0  390700.0       ...        1781000.0
# ...

# %%
city_grp.sort_values(['median_inc'])
# Out:
#                City  Unnamed: 0  median_inc    year      zip  RegionID  \
# 3   Borrego Springs        95.0     27369.0  2016.0  92004.0   96579.0
# 20    National City        88.0     37235.0  2016.0  91950.0   96567.0
# 4             Campo        72.0     38053.0  2016.0  91906.0   96542.0
# 26     San Clemente       243.0     38963.0  2016.0  92672.0   96982.0
# 14   Imperial Beach        81.0     43162.0  2016.0  91932.0   96555.0
# 10         El Cajon       103.0     47251.0  2016.0  92020.0   96589.0
# 16           Julian       111.0     49145.0  2016.0  92036.0   96601.0
# 33            Vista       133.0     50931.0  2016.0  92083.0   96633.0
# 19      Lemon Grove        86.0     54871.0  2016.0  91945.0   96563.0
# 12        Escondido       107.5     54905.0  2016.0  92026.5   96595.5
# 28       San Marcos       128.0     55428.5  2016.0  92073.5   96626.0
# 21        Oceanside       116.5     55433.0  2016.0  92056.5   96612.5
# ...
